# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("adm_data.csv")
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
df['Research'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.097526    -0.147932          -0.169948
# GRE Score           -0.097526   1.000000     0.835977           0.668976
# TOEFL Score         -0.147932   0.835977     1.000000           0.695590
# University Rating   -0.169948   0.668976     0.695590           1.000000
# SOP                 -0.166932   0.612831     0.657981           0.734523
# LOR                 -0.088221   0.557555     0.567721           0.660123
# CGPA                -0.045608   0.833060     0.828417           0.746479
# Research            -0.063138   0.580391     0.489858           0.447783
# Chance of Admit      0.042336   0.802610     0.791594           0.711250
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.166932 -0.088221 -0.045608 -0.063138          0.042336
# GRE Score          0.612831  0.557555  0.833060  0.580391          0.802610
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='BuPu')
# Out:
# <AxesSubplot:>

# %%
adm=corr['Chance of Admit ']
adm
# Out:
# Serial No.           0.042336
# GRE Score            0.802610
# TOEFL Score          0.791594
# University Rating    0.711250
# SOP                  0.675732
# LOR                  0.669889
# CGPA                 0.873289
# Research             0.553202
# Chance of Admit      1.000000
# Name: Chance of Admit , dtype: float64

# %%
adm_corr= pd.DataFrame(adm)
adm_corr
# Out:
#                    Chance of Admit
# Serial No.                 0.042336
# GRE Score                  0.802610
# TOEFL Score                0.791594
# University Rating          0.711250
# SOP                        0.675732
# LOR                        0.669889
# CGPA                       0.873289
# Research                   0.553202
# Chance of Admit            1.000000

# %%
sns.heatmap(adm_corr,annot=True,cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,8))
sns.regplot(data=df , y='GRE Score', x='Chance of Admit ')
# Out:
# <AxesSubplot:xlabel='Chance of Admit ', ylabel='GRE Score'>

# %%
plt.figure(figsize=(8,8))
sns.regplot(data=df, y="CGPA", x="Chance of Admit ")
# Out:
# <AxesSubplot:xlabel='Chance of Admit ', ylabel='CGPA'>

# %%
x=df.iloc[:,1:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
x_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 218        324          110                  4  3.0   3.5  8.97         1
# 188        331          115                  5  4.5   3.5  9.36         1
# 60         309          100                  2  3.0   3.0  8.10         0
# 281        317          110                  3  4.0   4.5  9.11         1
# 88         314          108                  3  4.5   3.5  8.14         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 117        290          104                  4  2.0   2.5  7.46         0
# 269        308          108                  4  4.5   5.0  8.34         0
# 97         331          120                  3  4.0   4.0  8.96         1
# 203        334          120                  5  4.0   5.0  9.87         1
# 115        310          106                  4  4.5   4.5  9.04         1
#
# [300 rows x 7 columns]

# %%
from sklearn import preprocessing

# %%
scaler=preprocessing.StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor

# %%
a=LinearRegression()
b=SVR()
c=RandomForestRegressor()
d=GradientBoostingRegressor()
e=AdaBoostRegressor()
reg_list=[a,b,c,d,e]

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

score={}

for reg in reg_list:
    reg.fit(x_train,y_train)
    predict=reg.predict(x_test)
    print('-'*50)
    print(reg)
    print(f"R2_score:{r2_score(y_test, predict)}")
    print(f"Mean Absolute Error Score : {mean_absolute_error(y_test,predict)}")
    print(f"Mean Sqaured Error Score : {mean_squared_error(y_test,predict)}")
    score[reg]={
        "R2 Score":r2_score(y_test,predict),
        "Mean Absolute Error Score":mean_absolute_error(y_test,predict),
        "Mean Squared Error Score":mean_squared_error(y_test,predict)
    }
# Out:
# --------------------------------------------------
# LinearRegression()
# R2_score:0.7704999229736929
# Mean Absolute Error Score : 0.047640622989141505
# Mean Sqaured Error Score : 0.004734228568932556
# --------------------------------------------------
# SVR()
# R2_score:0.6574094428378305
# Mean Absolute Error Score : 0.06717551249703613
# Mean Sqaured Error Score : 0.007067108752986383
# --------------------------------------------------
# RandomForestRegressor()
# R2_score:0.7579013875988687
# Mean Absolute Error Score : 0.04999899999999999
# Mean Sqaured Error Score : 0.004994116699999992
# --------------------------------------------------
# GradientBoostingRegressor()
# R2_score:0.7378231360372058
# Mean Absolute Error Score : 0.051175952156251946
# Mean Sqaured Error Score : 0.005408299707644662
# --------------------------------------------------
# AdaBoostRegressor()
# R2_score:0.7323842468838837
# Mean Absolute Error Score : 0.05735825677610893
# ...
